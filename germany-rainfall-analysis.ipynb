# %%
import pandas as pd

#C:\Users\HP\학교공부\2024_2학기\오픈소스개발프로젝트\플젝\2024-2_OS_Project\data
file_path = './data/rainfall.csv';
print(file_path)
df0 = pd.read_csv(file_path)

print(df0.head())
# Out:
# ./data/rainfall.csv
#      City  Latitude  Longitude  Month  Year  Rainfall (mm)  Elevation (m)  \
# 0  Berlin     52.52     13.405      1  2015          71.56             34
# 1  Berlin     52.52     13.405      2  2015         129.56             34
# 2  Berlin     52.52     13.405      3  2015          24.58             34
# 3  Berlin     52.52     13.405      4  2015         177.73             34
# 4  Berlin     52.52     13.405      5  2015         100.62             34
#
#   Climate_Type  Temperature (°C)  Humidity (%)
# 0      Oceanic              19.6            72
# 1      Oceanic              31.4            88
# 2      Oceanic              15.4            61
# 3      Oceanic              15.1            62
# 4      Oceanic              -3.0            57

# %%
df0.describe()
# Out:
#           Latitude    Longitude        Month         Year  Rainfall (mm)  \
# count  1080.000000  1080.000000  1080.000000  1080.000000    1080.000000
# mean     51.002410    10.242190     6.500000  2019.000000      99.211787
# std       1.576498     2.351316     3.453652     2.583185      57.560449
# min      48.135100     6.773500     1.000000  2015.000000       0.000000
# 25%      50.110900     8.682100     3.750000  2017.000000      49.500000
# 50%      51.139050     9.862850     6.500000  2019.000000      99.425000
# 75%      52.375900    12.373100     9.250000  2021.000000     149.527500
# max      53.551100    13.737300    12.000000  2023.000000     199.910000
#
#        Elevation (m)  Temperature (°C)  Humidity (%)
# count     1080.00000       1080.000000   1080.000000
# mean       127.20000         14.724259     65.153704
# std        145.90981         11.433380     20.303775
# min          6.00000         -5.000000     30.000000
# ...

# %%
df0.corr()
# Out:
#                       Latitude     Longitude         Month          Year  \
# Latitude          1.000000e+00  9.968173e-02 -1.876197e-16 -1.425619e-14
# Longitude         9.968173e-02  1.000000e+00 -2.655264e-16 -6.988524e-14
# Month            -1.876197e-16 -2.655264e-16  1.000000e+00  1.687003e-15
# Year             -1.425619e-14 -6.988524e-14  1.687003e-15  1.000000e+00
# Rainfall (mm)     6.594057e-04  1.601313e-03 -5.179921e-03 -1.361187e-02
# Elevation (m)    -8.447604e-01  2.105218e-01 -9.137074e-17 -1.544266e-14
# Temperature (°C)  2.382565e-02  1.632050e-02  2.121748e-02 -3.089015e-02
# Humidity (%)     -7.460791e-04  6.748604e-02 -2.059163e-02 -1.696358e-02
#
#                   Rainfall (mm)  Elevation (m)  Temperature (°C)  Humidity (%)
# Latitude               0.000659  -8.447604e-01          0.023826     -0.000746
# Longitude              0.001601   2.105218e-01          0.016320      0.067486
# ...

# %%
df_clean = df0.drop(['Latitude', 'Longitude', 'Elevation (m)'], axis=1) # drop latitude, logitude, elevation
print(df_clean.head())
# Out:
#      City  Month  Year  Rainfall (mm) Climate_Type  Temperature (°C)  \
# 0  Berlin      1  2015          71.56      Oceanic              19.6
# 1  Berlin      2  2015         129.56      Oceanic              31.4
# 2  Berlin      3  2015          24.58      Oceanic              15.4
# 3  Berlin      4  2015         177.73      Oceanic              15.1
# 4  Berlin      5  2015         100.62      Oceanic              -3.0
#
#    Humidity (%)
# 0            72
# 1            88
# 2            61
# 3            62
# 4            57

# %%
df_clean['Date'] = (df_clean['Year']-2015)*12+df_clean['Month'] # make new column 'Date'(2015.01 -> 1501, 2023.12 -> 2312)
print(df_clean.head())
# Out:
#      City  Month  Year  Rainfall (mm) Climate_Type  Temperature (°C)  \
# 0  Berlin      1  2015          71.56      Oceanic              19.6
# 1  Berlin      2  2015         129.56      Oceanic              31.4
# 2  Berlin      3  2015          24.58      Oceanic              15.4
# 3  Berlin      4  2015         177.73      Oceanic              15.1
# 4  Berlin      5  2015         100.62      Oceanic              -3.0
#
#    Humidity (%)  Date
# 0            72     1
# 1            88     2
# 2            61     3
# 3            62     4
# 4            57     5

# %%
df_clean.drop(['Year', 'Month'], axis=1, inplace=True) # drop year, month
print(df_clean.head())
# Out:
#      City  Rainfall (mm) Climate_Type  Temperature (°C)  Humidity (%)  Date
# 0  Berlin          71.56      Oceanic              19.6            72     1
# 1  Berlin         129.56      Oceanic              31.4            88     2
# 2  Berlin          24.58      Oceanic              15.4            61     3
# 3  Berlin         177.73      Oceanic              15.1            62     4
# 4  Berlin         100.62      Oceanic              -3.0            57     5

# %%
df_clean.drop(['Climate_Type'], axis=1, inplace=True) # drop climate type
print(df_clean.head())
# Out:
#      City  Rainfall (mm)  Temperature (°C)  Humidity (%)  Date
# 0  Berlin          71.56              19.6            72     1
# 1  Berlin         129.56              31.4            88     2
# 2  Berlin          24.58              15.4            61     3
# 3  Berlin         177.73              15.1            62     4
# 4  Berlin         100.62              -3.0            57     5

# %%
df_clean.set_index(['Date']) # set 'Date' as index
print(df_clean)
# Out:
#          City  Rainfall (mm)  Temperature (°C)  Humidity (%)  Date
# 0      Berlin          71.56              19.6            72     1
# 1      Berlin         129.56              31.4            88     2
# 2      Berlin          24.58              15.4            61     3
# 3      Berlin         177.73              15.1            62     4
# 4      Berlin         100.62              -3.0            57     5
# ...       ...            ...               ...           ...   ...
# 1075  Hanover          34.14              32.2            61   104
# 1076  Hanover           6.09              12.2            57   105
# 1077  Hanover          40.89              -0.2            30   106
# 1078  Hanover          68.08              15.5            89   107
# 1079  Hanover         102.12               9.0            85   108
#
# [1080 rows x 5 columns]

# %%
berlin = df_clean

#cities = pd.unique(newDf['City'])
#for i in range(len(newDf)):
#    city = newDf['City'][i]
#    for j in range(len(cities)):
#        if city == cities[j]:

for i in range(len(berlin)):
    if(berlin['City'][i] != 'Berlin'): # drop data if city is not Berlin
        berlin.drop(i, inplace=True)
        
print(berlin) # weather data of Berlin
# Out:
#        City  Rainfall (mm)  Temperature (°C)  Humidity (%)  Date
# 0    Berlin          71.56              19.6            72     1
# 1    Berlin         129.56              31.4            88     2
# 2    Berlin          24.58              15.4            61     3
# 3    Berlin         177.73              15.1            62     4
# 4    Berlin         100.62              -3.0            57     5
# ..      ...            ...               ...           ...   ...
# 103  Berlin         167.10              24.4            31   104
# 104  Berlin           2.94              16.3            39   105
# 105  Berlin          75.82               6.5            79   106
# 106  Berlin          67.47              14.7            41   107
# 107  Berlin           3.87               7.0            99   108
#
# [108 rows x 5 columns]

# %%
berlin = berlin.set_index(['Date']) # set 'Date' as index
print(berlin)
# Out:
#         City  Rainfall (mm)  Temperature (°C)  Humidity (%)
# Date
# 1     Berlin          71.56              19.6            72
# 2     Berlin         129.56              31.4            88
# 3     Berlin          24.58              15.4            61
# 4     Berlin         177.73              15.1            62
# 5     Berlin         100.62              -3.0            57
# ...      ...            ...               ...           ...
# 104   Berlin         167.10              24.4            31
# 105   Berlin           2.94              16.3            39
# 106   Berlin          75.82               6.5            79
# 107   Berlin          67.47              14.7            41
# 108   Berlin           3.87               7.0            99
#
# [108 rows x 4 columns]

# %%
berlin.plot() # plot of berlin's weather data  in time series
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
berlin.corr() # see correlations
# Out:
#                   Rainfall (mm)  Temperature (°C)  Humidity (%)
# Rainfall (mm)          1.000000         -0.010574      0.047555
# Temperature (°C)      -0.010574          1.000000     -0.144051
# Humidity (%)           0.047555         -0.144051      1.000000

# %%
berlin.plot(x='Rainfall (mm)', y='Temperature (°C)', kind='scatter') # scatter plot between rainfall and temp(Berlin)
berlin.plot(x='Rainfall (mm)', y='Humidity (%)', kind='scatter') # scatter plot between rainfall and humidity(Berlin)
# Out:
# <AxesSubplot:xlabel='Rainfall (mm)', ylabel='Humidity (%)'>

# %%
df0.plot(x='Rainfall (mm)', y='Temperature (°C)', kind='scatter') # scatter plot between rainfall and temp(all)
df0.plot(x='Rainfall (mm)', y='Humidity (%)', kind='scatter') # scatter plot between rainfall and humidity(all)
# Out:
# <AxesSubplot:xlabel='Rainfall (mm)', ylabel='Humidity (%)'>

# %%
grouped = df0.groupby(['Climate_Type']) # divide them in groups by climate type

for key, group in grouped:
    print('key: ', key)
    print('number: ', len(group))
    print(group.head())
    print('\n')
# Out:
# key:  Continental
# number:  432
#        City  Latitude  Longitude  Month  Year  Rainfall (mm)  Elevation (m)  \
# 108  Munich   48.1351     11.582      1  2015          24.87            519
# 109  Munich   48.1351     11.582      2  2015          82.73            519
# 110  Munich   48.1351     11.582      3  2015          98.57            519
# 111  Munich   48.1351     11.582      4  2015          80.86            519
# 112  Munich   48.1351     11.582      5  2015         106.19            519
#
#     Climate_Type  Temperature (°C)  Humidity (%)
# 108  Continental              18.8            51
# 109  Continental              12.4            61
# 110  Continental               1.6            30
# 111  Continental              -0.3            83
# 112  Continental              16.9            87
#
#
# key:  Oceanic
# number:  648
#      City  Latitude  Longitude  Month  Year  Rainfall (mm)  Elevation (m)  \
# ...

# %%
avg = grouped.mean() # average
print(avg)
# Out:
#                Latitude  Longitude  Month    Year  Rainfall (mm)  \
# Climate_Type
# Continental   49.825250  11.718825    6.5  2019.0     100.659259
# Oceanic       51.787183   9.257767    6.5  2019.0      98.246806
#
#               Elevation (m)  Temperature (°C)  Humidity (%)
# Climate_Type
# Continental           247.5         14.825694     66.023148
# Oceanic                47.0         14.656636     64.574074

# %%
std = grouped.std() # std
print(std)
# Out:
#             Latitude  Longitude     Month      Year  Rainfall (mm)  \
# City
# Berlin           0.0        0.0  3.468146  2.594026      56.299867
# Cologne          0.0        0.0  3.468146  2.594026      58.387136
# Dresden          0.0        0.0  3.468146  2.594026      57.727262
# Dusseldorf       0.0        0.0  3.468146  2.594026      54.275231
# Frankfurt        0.0        0.0  3.468146  2.594026      57.030150
# Hamburg          0.0        0.0  3.468146  2.594026      59.186303
# Hanover          0.0        0.0  3.468146  2.594026      54.305076
# Leipzig          0.0        0.0  3.468146  2.594026      60.542682
# Munich           0.0        0.0  3.468146  2.594026      61.244167
# Stuttgart        0.0        0.0  3.468146  2.594026      56.903129
#
#             Elevation (m)  Temperature (°C)  Humidity (%)
# City
# Berlin                0.0         11.837190     19.379309
# Cologne               0.0         11.540999     19.871104
# ...

# %%
print(grouped.corr()) # correlation
# Out:
#                                    Latitude     Longitude         Month  \
# Climate_Type
# Continental  Latitude          1.000000e+00  6.898319e-01  4.158286e-16
#              Longitude         6.898319e-01  1.000000e+00  2.148808e-16
#              Month             4.158286e-16  2.148808e-16  1.000000e+00
#              Year              1.124842e-13  2.719415e-14  6.884014e-15
#              Rainfall (mm)     3.210302e-02  4.184158e-02 -6.309378e-02
#              Elevation (m)    -8.934969e-01 -3.557527e-01 -5.261483e-16
#              Temperature (°C)  4.442531e-02  2.394679e-02  2.807385e-02
#              Humidity (%)      1.744509e-03 -4.546845e-02 -4.136220e-02
# Oceanic      Latitude          1.000000e+00  5.843247e-01 -5.154678e-16
#              Longitude         5.843247e-01  1.000000e+00 -5.083001e-16
#              Month            -5.154678e-16 -5.083001e-16  1.000000e+00
#              Year             -6.125159e-14 -1.141664e-13  3.643302e-15
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# swarmplot between climate type and rainfall
sns.swarmplot(x="Climate_Type",
             y="Rainfall (mm)",
             data=df0,
             ax=ax1)
#swarmplot between climate type and humidity
sns.swarmplot(x="Climate_Type",
             y="Humidity (%)",
             data=df0,
             ax=ax2)
ax1.set_title('climate type & rain')
ax2.set_title('climate type & humidity')

plt.show()

# %%
plt.style.use('seaborn-poster')
plt.rcParams['axes.unicode_minus']=False

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.boxplot(x=[df0[df0['Climate_Type']=='Oceanic']['Rainfall (mm)'],
                df0[df0['Climate_Type']=='Continental']['Rainfall (mm)']],
           labels=['oceanic', 'continental'])
ax2.boxplot(x=[df0[df0['Climate_Type']=='Oceanic']['Humidity (%)'],
                df0[df0['Climate_Type']=='Continental']['Humidity (%)']],
           labels=['oceanic', 'continental'],
           vert=False)
ax1.set_title('Rainfall distribution')
ax2.set_title('Humidity distribution')
plt.show()

# %%
print(df0.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              1080 non-null   object
#  1   Latitude          1080 non-null   float64
#  2   Longitude         1080 non-null   float64
#  3   Month             1080 non-null   int64
#  4   Year              1080 non-null   int64
#  5   Rainfall (mm)     1080 non-null   float64
#  6   Elevation (m)     1080 non-null   int64
#  7   Climate_Type      1080 non-null   object
#  8   Temperature (°C)  1080 non-null   float64
#  9   Humidity (%)      1080 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 84.5+ KB
# None

# %%
df0['Climate_Types'] = 0 # make new column 'Climate_Types'

# make climate type into integer type
for i in range(len(df0)):
    if df0['Climate_Type'][i] == 'Oceanic': # if type is Oceanic
        df0['Climate_Types'][i] = 1         # set 'Climate_Types' 1
    else:                                   # if type is Continental(not oceanic)
        df0['Climate_Types'][i] = 0         # set 'Climate_Type' 0

types = pd.unique(df0['Climate_Types']) # minimum check
print(types)

df0.drop(['Climate_Type'], axis=1, inplace=True) # drop 'Climate_Type'

print(df0)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_21416/3746775351.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Climate_Types'][i] = 1         # set 'Climate_Types' 1
# C:\Users\HP\AppData\Local\Temp/ipykernel_21416/3746775351.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0['Climate_Types'][i] = 0         # set 'Climate_Type' 0
# [1 0]
#          City  Latitude  Longitude  Month  Year  Rainfall (mm)  Elevation (m)  \
# 0      Berlin   52.5200     13.405      1  2015          71.56             34
# 1      Berlin   52.5200     13.405      2  2015         129.56             34
# ...

# %%
ndf = df0[['Climate_Types', 'Latitude', 'Longitude', 'Rainfall (mm)', 'Temperature (°C)', 'Humidity (%)']]
print(ndf.head())
print(ndf.info())
# Out:
#    Climate_Types  Latitude  Longitude  Rainfall (mm)  Temperature (°C)  \
# 0              1     52.52     13.405          71.56              19.6
# 1              1     52.52     13.405         129.56              31.4
# 2              1     52.52     13.405          24.58              15.4
# 3              1     52.52     13.405         177.73              15.1
# 4              1     52.52     13.405         100.62              -3.0
#
#    Humidity (%)
# 0            72
# 1            88
# 2            61
# 3            62
# 4            57
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Climate_Types     1080 non-null   int64
#  1   Latitude          1080 non-null   float64
#  2   Longitude         1080 non-null   float64
#  3   Rainfall (mm)     1080 non-null   float64
#  4   Temperature (°C)  1080 non-null   float64
# ...

# %%
# df0 = df0.astype({'Climate_Type':'int'})
# for i in range(len(df0)):
#     if df0['Climate_Type'][i] == 'Oceanic':
#         df0['Climate_Type'][i] = 1
#     else:
#         df0['Climate_Type'][i] = 0
        
# print(df0.head())
# print(df0.info())

# %%
x=df0[['Latitude', 'Longitude', 'Rainfall (mm)', 'Temperature (°C)', 'Humidity (%)']]
y=df0['Climate_Types']

from sklearn import preprocessing
x = preprocessing.StandardScaler().fit(x).transform(x)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=10)

print("train 개수: ", x_train.shape)
print('test 개수: ', x_test.shape)
# Out:
# train 개수:  (756, 5)
# test 개수:  (324, 5)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(x_train, y_train)

y_hat = knn.predict(x_test)

print(y_hat[0:10])
print(y_test.values[0:10])
# Out:
# [0 1 0 1 1 0 1 0 0 1]
# [0 1 0 1 1 0 1 0 0 1]

# %%
from sklearn import metrics
knn_matrix = metrics.confusion_matrix(y_test, y_hat)
print(knn_matrix)
# Out:
# [[131   1]
#  [  0 192]]
